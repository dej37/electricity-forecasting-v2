# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Top Prix\Downloads\Football_Player_Data-Analysis.csv")

# %%
df.columns
# Out:
# Index(['Player Name', 'Player Team', 'Team Formation', 'Player Age',
#        'Player Height', 'Position 1', 'Position 2', 'Mins Played',
#        'tacklePerGame', 'interceptionPerGame', 'foulsPerGame',
#        'clearancePerGame', 'wasDribbledPerGame', 'goal', 'assistTotal',
#        'shotsPerGame', 'keyPassPerGame', 'dribbleWonPerGame',
#        'foulGivenPerGame', 'offsideGivenPerGame', 'dispossessedPerGame',
#        'turnoverPerGame', 'totalPassesPerGame', 'passSuccess',
#        'accurateCrossesPerGame', 'accurateLongPassPerGame',
#        'accurateThroughBallPerGame', 'xG', 'xGPerNinety', 'totalShots',
#        'xGPerShot', 'rating'],
#       dtype='object')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# accurateCrossesPerGame        4
# accurateLongPassPerGame       4
# passSuccess                   4
# accurateThroughBallPerGame    4
# totalPassesPerGame            4
# Player Name                   0
# Team Formation                0
# Player Team                   0
# tacklePerGame                 0
# interceptionPerGame           0
# foulsPerGame                  0
# Player Age                    0
# Player Height                 0
# Position 1                    0
# Position 2                    0
# Mins Played                   0
# shotsPerGame                  0
# assistTotal                   0
# goal                          0
# wasDribbledPerGame            0
# clearancePerGame              0
# offsideGivenPerGame           0
# keyPassPerGame                0
# dribbleWonPerGame             0
# dispossessedPerGame           0
# turnoverPerGame               0
# foulGivenPerGame              0
# xG                            0
# xGPerNinety                   0
# totalShots                    0
# xGPerShot                     0
# rating                        0
# dtype: int64

# %%
df.shape
# Out:
# (1533, 32)

# %%
df['rating'].describe()
# Out:
# count    1533.000000
# mean        6.629798
# std         0.281165
# min         6.030000
# 25%         6.430000
# 50%         6.610000
# 75%         6.790000
# max         7.960000
# Name: rating, dtype: float64

# %%
df.dtypes
# Out:
# Player Name                    object
# Player Team                    object
# Team Formation                 object
# Player Age                      int64
# Player Height                   int64
# Position 1                     object
# Position 2                     object
# Mins Played                     int64
# tacklePerGame                 float64
# interceptionPerGame           float64
# foulsPerGame                  float64
# clearancePerGame              float64
# wasDribbledPerGame            float64
# goal                            int64
# assistTotal                     int64
# shotsPerGame                  float64
# keyPassPerGame                float64
# dribbleWonPerGame             float64
# foulGivenPerGame              float64
# offsideGivenPerGame           float64
# dispossessedPerGame           float64
# turnoverPerGame               float64
# totalPassesPerGame            float64
# passSuccess                   float64
# accurateCrossesPerGame        float64
# accurateLongPassPerGame       float64
# accurateThroughBallPerGame    float64
# xG                            float64
# xGPerNinety                    object
# totalShots                      int64
# xGPerShot                     float64
# rating                        float64
# dtype: object

# %%
df=df.fillna(df.mean(numeric_only=True))

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=20, kde=True)
plt.title('Distribution of Player Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['rating'], df['shotsPerGame'], alpha=0.5)
plt.title('Age vs. Rating')
plt.xlabel('Rating')
plt.ylabel('shots')
plt.show()
